# %%
import re
import jsonlines
import pandas as pd
import urllib.request
from bs4 import BeautifulSoup
from requests.exceptions import RequestException
import random
from time import sleep
from os import path

import comicvision.webscraper as webscraper

# %%
def strip_channel_from_title(title: str):
    channel = re.search(r"\[(.*?)\]", title)
    if channel is None:
        return title
    else:
        return title.split(channel.group())[0].strip()


def check_if_issue_is_variant(title: str, metadata_path: str) -> bool: 
    logged_metadata = []

    with jsonlines.open('./metadata/covers.jsonl', mode='r') as reader:
        for item in reader:
            logged_metadata.append(item)

    titles = list(pd.DataFrame(logged_metadata)['title'].values)
    
    return reduce(lambda x, y: x | y, [strip_channel_from_title(title) in x for x in titles])

# %%
# TODO: refactor this method to make it more functional and easier to test
# TODO: add tests!

def get_all_from_publisher_page(publisher_url: str, page: int):
    """
    Do a thing...
    """
    # global val
    URL = 'https://www.comics.org'

    # get publisher page
    publisher_html = webscraper.simple_get(publisher_url + '?page={}'.format(page))
    publisher_soup = webscraper.transform_simple_get_html(publisher_html)
    
    # parse series table from publisher page
    series_name = [result.find('a').contents[0] for result in publisher_soup.find_all('td', {'class': 'name'})]
    series_href = [result.find('a')['href'] for result in  publisher_soup.find_all('td', {'class': 'name'})]
    series_year = [result.contents[0] for result in publisher_soup.find_all('td', {'class': 'year'})]
    series_issue_count = [result.contents[0] for result in publisher_soup.find_all('td', {'class': 'issue_count'})]
    series_published = [result.contents[0] for result in publisher_soup.find_all('td', {'class': 'published'})]
    
    # create dataframe of publisher series (on page)
    series_df = pd.DataFrame(list(zip(series_name, series_href, series_year, series_issue_count, series_published)),
                             columns=['name', 'href', 'year', 'issue_count', 'published'])

    # parse issue count as int from issue_count column
    series_df['issue_count_int'] = series_df['issue_count'].apply(lambda x: int(re.search(r'\d+', x).group()))

    # iterate over series dataframe and get issue covers and metadata
    for series_name, series_page_href, issue_count in zip(series_df['name'], series_df['href'], series_df['issue_count_int']):
        
        if issue_count < 12:
            pass
        else:
            print(series_name, series_page_href, issue_count)
            
            # construct series page url
            series_page_url  = URL + series_page_href

            # get series page
            series_page_html = webscraper.simple_get(series_page_url)
            series_page_soup = webscraper.transform_simple_get_html(series_page_html)

            # get cover gallery url for series
            if series_page_soup.find('a',  href=True, text='Cover Gallery') is None:
                pass
            else:
                cover_gallery_href = series_page_soup.find('a',  href=True, text='Cover Gallery')['href']
                cover_gallery_base_url = URL + cover_gallery_href

                # get cover gallery page
                cover_gallery_html = webscraper.simple_get(cover_gallery_base_url)
                cover_gallery_soup = webscraper.transform_simple_get_html(cover_gallery_html)

                if len(cover_gallery_soup.find_all('a', {'class': "btn btn-default btn-sm"})) == 0:

                    # get issue hrefs from all linked issues on cover gallery
                    cover_gallery_hrefs = filter(lambda x: '/issue/' in x['href'] and '/cover/' not in x['href'], cover_gallery_soup.find_all('a',  href=True))
                    issue_hrefs = [x['href'] for x in cover_gallery_hrefs]

                    #  construct issue urls from issue hrefs
                    issue_urls = [URL + issue_href for issue_href in  issue_hrefs]

                    # scrape issues
                    for issue_url in issue_urls:

                        # get issue page
                        issue_html = webscraper.simple_get(issue_url)
                        issue_soup = webscraper.transform_simple_get_html(issue_html)

                        # metadata
                        metadata = {}
                        metadata['series_name'] = series_name.replace('/', '|')

                        # scrape metadata from issue page
                        # title, price, pages, color, dimension, paper_stock, binding, publishing_format
                        def get_issue_metadata(soup, name):
                            if len(soup.find_all('dd', id=name)) > 0:
                                if (name != 'issue_indicia_publisher') & (name != 'issue_brand'):
                                    return soup.find_all('dd', id=name)[0].contents[0].strip()
                                else:
                                    try:
                                        return soup.find_all('dd', id=name)[0].find('a').contents[0]
                                    except:
                                        return ""
                            else:
                                return ""

                        # post process the issue title removing extraneous characters
                        metadata['title'] = issue_soup.find('title').contents[0].replace('\n', '').strip().split(' :: ')[-1].replace('/', '|')

                        # check if issue is redundant to an issue  already we pulled (variant)
                        if path.exists('./metadata/covers.jsonl'):
                            is_variant = check_if_issue_is_variant(title=metadata['title'], metadata_path='./metadata/covers.jsonl')
                            if is_variant:
                                pass
                            else:
                                metadata['on_sale_date'] = get_issue_metadata(issue_soup, name='on_sale_date')
                                metadata['indicia_frequency'] = get_issue_metadata(issue_soup, name='indicia_frequency')
                                metadata['issue_indicia_publisher'] = get_issue_metadata(issue_soup, name='issue_indicia_publisher')
                                metadata['issue_brand'] = get_issue_metadata(issue_soup, name='issue_brand')
                                metadata['issue_price'] = get_issue_metadata(issue_soup, name='issue_price')
                                metadata['issue_pages'] = get_issue_metadata(issue_soup, name='issue_pages')
                                metadata['format_color'] = get_issue_metadata(issue_soup, name='format_color')
                                metadata['format_dimensions'] = get_issue_metadata(issue_soup, name='format_dimensions')
                                metadata['format_paper_stock'] = get_issue_metadata(issue_soup, name='format_paper_stock')
                                metadata['format_binding'] = get_issue_metadata(issue_soup, name='format_binding')
                                metadata['format_publishing_format'] = get_issue_metadata(issue_soup, name='format_publishing_format')
                                metadata['rating'] = get_issue_metadata(issue_soup, name='rating')
                                metadata['indexer_notes'] = " | ".join([x.contents[0].replace('\n', '').strip() for x in issue_soup.find_all('p')])

                                all_issue_credits = list(zip(
                                    issue_soup.find_all('span', {'class': 'credit_label'}),  
                                    issue_soup.find_all('span', {'class': 'credit_value'})))

                                metadata['synopsis'] = " | ".join(list(filter(lambda x: x != '', [x[1].contents[0] if x[0].contents[0] == 'Synopsis' else '' for x in all_issue_credits])))

                                # get cover section
                                cover = issue_soup.find("div", {"class": "cover"})

                                # cover credits: editing, script, pencils, inks, colors, letters, characters, etc...
                                cover_credits = list(zip(
                                    [result.contents[0] for result in cover.find_all('span', {'class': 'credit_label'})],
                                    [result.contents[0] for result in cover.find_all('span', {'class': 'credit_value'})]
                                ))

                                metadata.update({'cover_{}'.format(x.lower()): y for x, y in cover_credits})
                                metadata.pop('cover_reprints', None)

                                # get the cover url
                                cover_img_href = cover.find("div", {'coverImage'}).a['href']
                                cover_img_url = URL + cover_img_href

                                # get cover page
                                cover_img_html = webscraper.simple_get(cover_img_url)
                                cover_img_soup = webscraper.transform_simple_get_html(cover_img_html)

                                # get image urls from cover page
                                cover_images = cover_img_soup.select('img')

                                # get raw, highest res image
                                cover_images = list(filter(lambda x:'files1.comics.org//img/' in x['src'], cover_images))
                                cover = cover_images[0]['src']

                                # construct where to save the cover image
                                save_as = "{} -- {}".format(metadata['series_name'], metadata['title'])
                                save_to = './covers/' + save_as + '.jpg'

                                metadata["cover_image_file_name"] = save_as

                                # save cover image
                                urllib.request.urlretrieve(cover, save_to)

                                # TODO: reason about response of save; if successful, save metadata, else contine
                                # save metadata
                                with jsonlines.open('./metadata/covers.jsonl', mode='a') as writer:
                                    writer.write(metadata)

                                # TODO: write to log... timestamp/publisher/series/issue/
                                now = datetime.datetime.today().strftime("%d/%m/%Y %H:%M:%S")
                                publisher_int = publisher_url.split('/')[-2]

                                log = {'timestamp': now, 'publisher': publisher_int, 'series': metadata['series_name'],  'issue': metadata['title']}
                                with jsonlines.open('./metadata/log.jsonl', mode='a') as writer:
                                    writer.write(log)

                                # slow down the requests so we don't take too many resources and get blocked
                                sleep(random.uniform(5, 10))

                        else:
                            metadata['on_sale_date'] = get_issue_metadata(issue_soup, name='on_sale_date')
                            metadata['indicia_frequency'] = get_issue_metadata(issue_soup, name='indicia_frequency')
                            metadata['issue_indicia_publisher'] = get_issue_metadata(issue_soup, name='issue_indicia_publisher')
                            metadata['issue_brand'] = get_issue_metadata(issue_soup, name='issue_brand')
                            metadata['issue_price'] = get_issue_metadata(issue_soup, name='issue_price')
                            metadata['issue_pages'] = get_issue_metadata(issue_soup, name='issue_pages')
                            metadata['format_color'] = get_issue_metadata(issue_soup, name='format_color')
                            metadata['format_dimensions'] = get_issue_metadata(issue_soup, name='format_dimensions')
                            metadata['format_paper_stock'] = get_issue_metadata(issue_soup, name='format_paper_stock')
                            metadata['format_binding'] = get_issue_metadata(issue_soup, name='format_binding')
                            metadata['format_publishing_format'] = get_issue_metadata(issue_soup, name='format_publishing_format')
                            metadata['rating'] = get_issue_metadata(issue_soup, name='rating')
                            metadata['indexer_notes'] = " | ".join([x.contents[0].replace('\n', '').strip() for x in issue_soup.find_all('p')])

                            all_issue_credits = list(zip(
                                issue_soup.find_all('span', {'class': 'credit_label'}), 
                                issue_soup.find_all('span', {'class': 'credit_value'})))

                            metadata['synopsis'] = " | ".join(list(filter(lambda x: x != '', [x[1].contents[0] if x[0].contents[0] == 'Synopsis' else '' for x in all_issue_credits])))

                            # get cover section
                            cover = issue_soup.find("div", {"class": "cover"})

                            # cover credits: editing, script, pencils, inks, colors, letters, characters, etc...
                            cover_credits = list(zip(
                                [result.contents[0] for result in cover.find_all('span', {'class': 'credit_label'})],
                                [result.contents[0] for result in cover.find_all('span', {'class': 'credit_value'})]
                            ))

                            metadata.update({'cover_{}'.format(x.lower()): y for x, y in cover_credits})
                            metadata.pop('cover_reprints', None)

                            # get the cover url
                            cover_img_href = cover.find("div", {'coverImage'}).a['href']
                            cover_img_url = URL + cover_img_href

                            # get cover page
                            cover_img_html = webscraper.simple_get(cover_img_url)
                            cover_img_soup = webscraper.transform_simple_get_html(cover_img_html)

                            # get image urls from cover page
                            cover_images = cover_img_soup.select('img')

                            # get raw, highest res image
                            cover_images = list(filter(lambda x:'files1.comics.org//img/' in x['src'], cover_images))
                            cover = cover_images[0]['src']

                            # construct where to save the cover image
                            save_as = "{} -- {}".format(metadata['series_name'], metadata['title'])
                            save_to = './covers/' + save_as + '.jpg'

                            metadata["cover_image_file_name"] = save_as

                            # save cover image
                            urllib.request.urlretrieve(cover, save_to)

                            # TODO: reason about response of save; if successful, save metadata, else contine
                            # save metadata
                            with jsonlines.open('./metadata/covers.jsonl', mode='a') as writer:
                                writer.write(metadata)

                            # TODO: write to log... timestamp/publisher/series/issue/
                            now = datetime.datetime.today().strftime("%d/%m/%Y %H:%M:%S")
                            publisher_int = publisher_url.split('/')[-2]

                            log = {'timestamp': now, 'publisher': publisher_int, 'series': metadata['series_name'],  'issue': metadata['title']}
                            with jsonlines.open('./metadata/log.jsonl', mode='a') as writer:
                                writer.write(log)

                            # slow down the requests so we don't take too many resources and get blocked
                            sleep(random.uniform(5, 10))
                else:
                    cover_gallery_pages = list(filter(lambda x: x.isdigit(), [x.contents[0] for x in cover_gallery_soup.find_all('a', {'class': "btn btn-default btn-sm"})]))
                    cover_gallery_range = max([int(x) for x in cover_gallery_pages])

                    for i in range(1, cover_gallery_range + 1):
                        cover_gallery_url = str(cover_gallery_base_url + '/?page={}').format(i)
                        cover_gallery_html = webscraper.simple_get(cover_gallery_url)
                        cover_gallery_soup = webscraper.transform_simple_get_html(cover_gallery_html)

                        # get issue hrefs from all linked issues on cover gallery
                        cover_gallery_hrefs = filter(lambda x: '/issue/' in x['href'] and '/cover/' not in x['href'], cover_gallery_soup.find_all('a',  href=True))
                        issue_hrefs = [x['href'] for x in cover_gallery_hrefs]

                        #  construct issue urls from issue hrefs
                        issue_urls = [URL + issue_href for issue_href in  issue_hrefs]

                        # scrape issues
                        for issue_url in issue_urls:

                            # get issue page
                            issue_html = webscraper.simple_get(issue_url)
                            issue_soup = webscraper.transform_simple_get_html(issue_html)

                            # metadata
                            metadata = {}
                            metadata['series_name'] = series_name.replace('/', '|')

                            # scrape metadata from issue page
                            # title, price, pages, color, dimension, paper_stock, binding, publishing_format
                            def get_issue_metadata(soup, name):
                                if len(soup.find_all('dd', id=name)) > 0:
                                    if (name != 'issue_indicia_publisher') & (name != 'issue_brand'):
                                        return soup.find_all('dd', id=name)[0].contents[0].strip()
                                    else:
                                        try:
                                            return soup.find_all('dd', id=name)[0].find('a').contents[0]
                                        except:
                                            return ""
                                else:
                                    return ""

                            metadata['title'] = issue_soup.find('title').contents[0].replace('\n', '').strip().split(' :: ')[-1].replace('/', '|')

                            # check if issue is redundant to an issue  already we pulled (variant)
                            if path.exists('./metadata/covers.jsonl'):
                                is_variant = check_if_issue_is_variant(title=metadata['title'], metadata_path='./metadata/covers.jsonl')
                                if is_variant:
                                    pass
                                else:
                                    metadata['on_sale_date'] = get_issue_metadata(issue_soup, name='on_sale_date')
                                    metadata['indicia_frequency'] = get_issue_metadata(issue_soup, name='indicia_frequency')
                                    metadata['issue_indicia_publisher'] = get_issue_metadata(issue_soup, name='issue_indicia_publisher')
                                    metadata['issue_brand'] = get_issue_metadata(issue_soup, name='issue_brand')
                                    metadata['issue_price'] = get_issue_metadata(issue_soup, name='issue_price')
                                    metadata['issue_pages'] = get_issue_metadata(issue_soup, name='issue_pages')
                                    metadata['format_color'] = get_issue_metadata(issue_soup, name='format_color')
                                    metadata['format_dimensions'] = get_issue_metadata(issue_soup, name='format_dimensions')
                                    metadata['format_paper_stock'] = get_issue_metadata(issue_soup, name='format_paper_stock')
                                    metadata['format_binding'] = get_issue_metadata(issue_soup, name='format_binding')
                                    metadata['format_publishing_format'] = get_issue_metadata(issue_soup, name='format_publishing_format')
                                    metadata['rating'] = get_issue_metadata(issue_soup, name='rating')
                                    metadata['indexer_notes'] = " | ".join([x.contents[0].replace('\n', '').strip() for x in issue_soup.find_all('p')])

                                    all_issue_credits = list(zip(
                                        issue_soup.find_all('span', {'class': 'credit_label'}),  
                                        issue_soup.find_all('span', {'class': 'credit_value'})))

                                    metadata['synopsis'] = " | ".join(list(filter(lambda x: x != '', [x[1].contents[0] if x[0].contents[0] == 'Synopsis' else '' for x in all_issue_credits])))

                                    # get cover section
                                    cover = issue_soup.find("div", {"class": "cover"})

                                    # cover credits: editing, script, pencils, inks, colors, letters, characters, etc...
                                    cover_credits = list(zip(
                                        [result.contents[0] for result in cover.find_all('span', {'class': 'credit_label'})],
                                        [result.contents[0] for result in cover.find_all('span', {'class': 'credit_value'})]
                                    ))

                                    metadata.update({'cover_{}'.format(x.lower()): y for x, y in cover_credits})
                                    metadata.pop('cover_reprints', None)

                                    # get the cover url
                                    cover_img_href = cover.find("div", {'coverImage'}).a['href']
                                    cover_img_url = URL + cover_img_href

                                    # get cover page
                                    cover_img_html = webscraper.simple_get(cover_img_url)
                                    cover_img_soup = webscraper.transform_simple_get_html(cover_img_html)

                                    # get image urls from cover page
                                    cover_images = cover_img_soup.select('img')

                                    # get raw, highest res image
                                    cover_images = list(filter(lambda x:'files1.comics.org//img/' in x['src'], cover_images))
                                    cover = cover_images[0]['src']

                                    # construct where to save the cover image
                                    save_as = "{} -- {}".format(metadata['series_name'], metadata['title'])
                                    save_to = './covers/' + save_as + '.jpg'

                                    metadata["cover_image_file_name"] = save_as

                                    # save cover image
                                    urllib.request.urlretrieve(cover, save_to)

                                    # TODO: reason about response of save; if successful, save metadata, else contine
                                    # save metadata
                                    with jsonlines.open('./metadata/covers.jsonl', mode='a') as writer:
                                        writer.write(metadata)

                                    # TODO: write to log... timestamp/publisher/series/issue/
                                    now = datetime.datetime.today().strftime("%d/%m/%Y %H:%M:%S")
                                    publisher_int = publisher_url.split('/')[-2]

                                    log = {'timestamp': now, 'publisher': publisher_int, 'series': metadata['series_name'],  'issue': metadata['title']}
                                    with jsonlines.open('./metadata/log.jsonl', mode='a') as writer:
                                        writer.write(log)

                                    # slow down the requests so we don't take too many resources and get blocked
                                    sleep(random.uniform(5, 10))

                            else:
                                metadata['on_sale_date'] = get_issue_metadata(issue_soup, name='on_sale_date')
                                metadata['indicia_frequency'] = get_issue_metadata(issue_soup, name='indicia_frequency')
                                metadata['issue_indicia_publisher'] = get_issue_metadata(issue_soup, name='issue_indicia_publisher')
                                metadata['issue_brand'] = get_issue_metadata(issue_soup, name='issue_brand')
                                metadata['issue_price'] = get_issue_metadata(issue_soup, name='issue_price')
                                metadata['issue_pages'] = get_issue_metadata(issue_soup, name='issue_pages')
                                metadata['format_color'] = get_issue_metadata(issue_soup, name='format_color')
                                metadata['format_dimensions'] = get_issue_metadata(issue_soup, name='format_dimensions')
                                metadata['format_paper_stock'] = get_issue_metadata(issue_soup, name='format_paper_stock')
                                metadata['format_binding'] = get_issue_metadata(issue_soup, name='format_binding')
                                metadata['format_publishing_format'] = get_issue_metadata(issue_soup, name='format_publishing_format')
                                metadata['rating'] = get_issue_metadata(issue_soup, name='rating')
                                metadata['indexer_notes'] = " | ".join([x.contents[0].replace('\n', '').strip() for x in issue_soup.find_all('p')])

                                all_issue_credits = list(zip(
                                    issue_soup.find_all('span', {'class': 'credit_label'}), 
                                    issue_soup.find_all('span', {'class': 'credit_value'})))

                                metadata['synopsis'] = " | ".join(list(filter(lambda x: x != '', [x[1].contents[0] if x[0].contents[0] == 'Synopsis' else '' for x in all_issue_credits])))

                                # get cover section
                                cover = issue_soup.find("div", {"class": "cover"})

                                # cover credits: editing, script, pencils, inks, colors, letters, characters, etc...
                                cover_credits = list(zip(
                                    [result.contents[0] for result in cover.find_all('span', {'class': 'credit_label'})],
                                    [result.contents[0] for result in cover.find_all('span', {'class': 'credit_value'})]
                                ))

                                metadata.update({'cover_{}'.format(x.lower()): y for x, y in cover_credits})
                                metadata.pop('cover_reprints', None)

                                # get the cover url
                                cover_img_href = cover.find("div", {'coverImage'}).a['href']
                                cover_img_url = URL + cover_img_href

                                # get cover page
                                cover_img_html = webscraper.simple_get(cover_img_url)
                                cover_img_soup = webscraper.transform_simple_get_html(cover_img_html)

                                # get image urls from cover page
                                cover_images = cover_img_soup.select('img')

                                # get raw, highest res image
                                cover_images = list(filter(lambda x:'files1.comics.org//img/' in x['src'], cover_images))
                                cover = cover_images[0]['src']

                                # construct where to save the cover image
                                save_as = "{} -- {}".format(metadata['series_name'], metadata['title'])
                                save_to = './covers/' + save_as + '.jpg'

                                metadata["cover_image_file_name"] = save_as

                                # save cover image
                                urllib.request.urlretrieve(cover, save_to)

                                # TODO: reason about response of save; if successful, save metadata, else contine
                                # save metadata
                                with jsonlines.open('./metadata/covers.jsonl', mode='a') as writer:
                                    writer.write(metadata)

                                # TODO: write to log... timestamp/publisher/series/issue/
                                now = datetime.datetime.today().strftime("%d/%m/%Y %H:%M:%S")
                                publisher_int = publisher_url.split('/')[-2]

                                log = {'timestamp': now, 'publisher': publisher_int, 'series': metadata['series_name'],  'issue': metadata['title']}
                                with jsonlines.open('./metadata/log.jsonl', mode='a') as writer:
                                    writer.write(log)

                                # slow down the requests so we don't take too many resources and get blocked
                                sleep(random.uniform(5, 10))

# %%
get_all_from_publisher_page(publisher_url='https://www.comics.org/publisher/54/', page=3)
# Out:
# All-American Western /series/532/ 24
# All-Flash /series/211/ 32
# The All-New Batman: The Brave and the Bold /series/53270/ 16
# All-Star Comics /series/140/ 57
# https://www.comics.org/issue/877/
# https://www.comics.org/issue/1037/
# https://www.comics.org/issue/1205/
# https://www.comics.org/issue/935246/
# https://www.comics.org/issue/1291/
# https://www.comics.org/issue/1443/
# https://www.comics.org/issue/1551/
# https://www.comics.org/issue/1681/
# https://www.comics.org/issue/1816/
# https://www.comics.org/issue/1980/
# https://www.comics.org/issue/2094/
# https://www.comics.org/issue/2206/
# https://www.comics.org/issue/2322/
# https://www.comics.org/issue/2422/
# https://www.comics.org/issue/2545/
# https://www.comics.org/issue/2703/
# https://www.comics.org/issue/2822/
# https://www.comics.org/issue/2934/
# https://www.comics.org/issue/3160/
# https://www.comics.org/issue/3361/
# https://www.comics.org/issue/3530/
# https://www.comics.org/issue/3691/
# https://www.comics.org/issue/3862/
# https://www.comics.org/issue/4110/
# https://www.comics.org/issue/4279/
# https://www.comics.org/issue/4439/
# https://www.comics.org/issue/4588/
# https://www.comics.org/issue/4795/
# https://www.comics.org/issue/4973/
# https://www.comics.org/issue/5105/
# https://www.comics.org/issue/5242/
# https://www.comics.org/issue/5365/
# https://www.comics.org/issue/5504/
# https://www.comics.org/issue/5678/
# https://www.comics.org/issue/5795/
# https://www.comics.org/issue/5924/
# https://www.comics.org/issue/6053/
# https://www.comics.org/issue/6172/
# https://www.comics.org/issue/6312/
# https://www.comics.org/issue/6482/
# https://www.comics.org/issue/6609/
# https://www.comics.org/issue/6751/
# https://www.comics.org/issue/6887/
# https://www.comics.org/issue/7020/
# https://www.comics.org/issue/7163/
# https://www.comics.org/issue/7311/
# https://www.comics.org/issue/7457/
# https://www.comics.org/issue/7590/
# https://www.comics.org/issue/7716/
# https://www.comics.org/issue/7828/
# https://www.comics.org/issue/7930/
# https://www.comics.org/issue/8069/
# https://www.comics.org/issue/8180/
# https://www.comics.org/issue/8280/
# https://www.comics.org/issue/8372/
# https://www.comics.org/issue/8464/
# https://www.comics.org/issue/8554/
# https://www.comics.org/issue/8698/
# All-Star Comics /series/2321/ 17
# All-Star Squadron /series/2583/ 67
# https://www.comics.org/issue/35606/
# https://www.comics.org/issue/875352/
# https://www.comics.org/issue/35689/
# https://www.comics.org/issue/1649711/
# https://www.comics.org/issue/35771/
# https://www.comics.org/issue/1654379/
# https://www.comics.org/issue/35842/
# https://www.comics.org/issue/1540491/
# https://www.comics.org/issue/35982/
# https://www.comics.org/issue/1540492/
# https://www.comics.org/issue/36060/
# https://www.comics.org/issue/1649712/
# https://www.comics.org/issue/36151/
# https://www.comics.org/issue/1687580/
# https://www.comics.org/issue/36235/
# https://www.comics.org/issue/1649714/
# https://www.comics.org/issue/36320/
# https://www.comics.org/issue/1649715/
# https://www.comics.org/issue/36396/
# https://www.comics.org/issue/1540494/
# https://www.comics.org/issue/36477/
# https://www.comics.org/issue/1649716/
# https://www.comics.org/issue/36553/
# https://www.comics.org/issue/1649717/
# https://www.comics.org/issue/36633/
# https://www.comics.org/issue/1649750/
# https://www.comics.org/issue/36710/
# https://www.comics.org/issue/1540495/
# https://www.comics.org/issue/1807389/
# https://www.comics.org/issue/36792/
# https://www.comics.org/issue/1634869/
# https://www.comics.org/issue/1634882/
# https://www.comics.org/issue/36875/
# https://www.comics.org/issue/1540496/
# https://www.comics.org/issue/37008/
# https://www.comics.org/issue/1540498/
# https://www.comics.org/issue/37087/
# https://www.comics.org/issue/1036550/
# https://www.comics.org/issue/1835423/
# https://www.comics.org/issue/37182/
# https://www.comics.org/issue/1040288/
# https://www.comics.org/issue/1800563/
# https://www.comics.org/issue/37267/
# https://www.comics.org/issue/1052944/
# https://www.comics.org/issue/37363/
# https://www.comics.org/issue/1087071/
# https://www.comics.org/issue/37456/
# https://www.comics.org/issue/1095243/
# https://www.comics.org/issue/37548/
# https://www.comics.org/issue/1099090/
# https://www.comics.org/issue/1627105/
# https://www.comics.org/issue/37637/
# https://www.comics.org/issue/1115653/
# https://www.comics.org/issue/37723/
# https://www.comics.org/issue/1119866/
# https://www.comics.org/issue/1634871/
# https://www.comics.org/issue/37812/
# https://www.comics.org/issue/1124126/
# https://www.comics.org/issue/1800564/
# https://www.comics.org/issue/37899/
# https://www.comics.org/issue/1126200/
# https://www.comics.org/issue/1800565/
# https://www.comics.org/issue/38006/
# https://www.comics.org/issue/1131253/
# https://www.comics.org/issue/1704832/
# https://www.comics.org/issue/38158/
# https://www.comics.org/issue/1131546/
# https://www.comics.org/issue/875229/
# https://www.comics.org/issue/38268/
# https://www.comics.org/issue/1134067/
# https://www.comics.org/issue/38389/
# https://www.comics.org/issue/1137222/
# https://www.comics.org/issue/1704833/
# https://www.comics.org/issue/38504/
# https://www.comics.org/issue/1137552/
# https://www.comics.org/issue/1634872/
# https://www.comics.org/issue/38615/
# https://www.comics.org/issue/1137736/
# https://www.comics.org/issue/1634875/
# https://www.comics.org/issue/38723/
# https://www.comics.org/issue/1138900/
# https://www.comics.org/issue/1917557/
# https://www.comics.org/issue/38833/
# https://www.comics.org/issue/1139015/
# https://www.comics.org/issue/1917558/
# https://www.comics.org/issue/38935/
# https://www.comics.org/issue/1139232/
# https://www.comics.org/issue/1634876/
# https://www.comics.org/issue/39049/
# https://www.comics.org/issue/1139275/
# https://www.comics.org/issue/1634877/
# https://www.comics.org/issue/39142/
# https://www.comics.org/issue/1139512/
# https://www.comics.org/issue/1634878/
# https://www.comics.org/issue/39244/
# https://www.comics.org/issue/1139527/
# https://www.comics.org/issue/1704841/
# https://www.comics.org/issue/39355/
# https://www.comics.org/issue/1437641/
# https://www.comics.org/issue/1634879/
# https://www.comics.org/issue/39537/
# https://www.comics.org/issue/1437673/
# https://www.comics.org/issue/1704834/
# https://www.comics.org/issue/39631/
# https://www.comics.org/issue/1601493/
# https://www.comics.org/issue/1800566/
# https://www.comics.org/issue/39736/
# https://www.comics.org/issue/1602185/
# https://www.comics.org/issue/1602184/
# https://www.comics.org/issue/39832/
# https://www.comics.org/issue/1540488/
# https://www.comics.org/issue/39950/
# https://www.comics.org/issue/1540490/
# https://www.comics.org/issue/1762404/
# https://www.comics.org/issue/40048/
# https://www.comics.org/issue/1602144/
# https://www.comics.org/issue/1800567/
# https://www.comics.org/issue/40163/
# https://www.comics.org/issue/1602145/
# https://www.comics.org/issue/1634880/
# https://www.comics.org/issue/40266/
# https://www.comics.org/issue/1835424/
# https://www.comics.org/issue/40374/
# https://www.comics.org/issue/1540489/
# https://www.comics.org/issue/40478/
# https://www.comics.org/issue/1649751/
# https://www.comics.org/issue/1704839/
# https://www.comics.org/issue/40594/
# https://www.comics.org/issue/900761/
# https://www.comics.org/issue/40710/
# https://www.comics.org/issue/900762/
# https://www.comics.org/issue/1704835/
# https://www.comics.org/issue/40935/
# https://www.comics.org/issue/1145087/
# https://www.comics.org/issue/1704837/
# https://www.comics.org/issue/41048/
# https://www.comics.org/issue/1103930/
# https://www.comics.org/issue/1704836/
# https://www.comics.org/issue/41159/
# https://www.comics.org/issue/1623969/
# https://www.comics.org/issue/1704859/
# https://www.comics.org/issue/41259/
# https://www.comics.org/issue/1681670/
# https://www.comics.org/issue/1704860/
# https://www.comics.org/issue/41364/
# https://www.comics.org/issue/1682135/
# https://www.comics.org/issue/1704861/
# https://www.comics.org/issue/41464/
# https://www.comics.org/issue/1649752/
# https://www.comics.org/issue/1805884/
# https://www.comics.org/issue/41575/
# https://www.comics.org/issue/900733/
# https://www.comics.org/issue/41680/
# https://www.comics.org/issue/1540497/
# https://www.comics.org/issue/41784/
# https://www.comics.org/issue/1805885/
# https://www.comics.org/issue/41882/
# https://www.comics.org/issue/1682713/
# https://www.comics.org/issue/42001/
# https://www.comics.org/issue/900763/
# https://www.comics.org/issue/42115/
# https://www.comics.org/issue/900764/
# https://www.comics.org/issue/42330/
# https://www.comics.org/issue/900765/
# https://www.comics.org/issue/42447/
# https://www.comics.org/issue/42566/
# https://www.comics.org/issue/1682934/
# https://www.comics.org/issue/1925799/
# The Amazing World of DC Comics /series/10512/ 17
# American Century /series/10051/ 27
# American Vampire /series/45315/ 34
# American Virgin /series/17501/ 23
# Amethyst /series/2969/ 16
# Amethyst, Princess of Gemworld /series/2713/ 12
# Anima /series/4939/ 16
# Animal Antics /series/455/ 23
# Animal Man /series/3567/ 89
# https://www.comics.org/issue/44905/
# https://www.comics.org/issue/45039/
# https://www.comics.org/issue/45180/
# https://www.comics.org/issue/45319/
# https://www.comics.org/issue/45566/
# https://www.comics.org/issue/45574/
# https://www.comics.org/issue/45687/
# https://www.comics.org/issue/45819/
# https://www.comics.org/issue/45942/
# https://www.comics.org/issue/46060/
# https://www.comics.org/issue/46186/
# https://www.comics.org/issue/46302/
# https://www.comics.org/issue/46425/
# https://www.comics.org/issue/46543/
# https://www.comics.org/issue/46667/
# https://www.comics.org/issue/46797/
# https://www.comics.org/issue/46918/
# https://www.comics.org/issue/47069/
# https://www.comics.org/issue/47423/
# https://www.comics.org/issue/47535/
# https://www.comics.org/issue/47645/
# https://www.comics.org/issue/47769/
# https://www.comics.org/issue/47882/
# https://www.comics.org/issue/48003/
# https://www.comics.org/issue/48146/
# https://www.comics.org/issue/48276/
# https://www.comics.org/issue/48410/
# https://www.comics.org/issue/48546/
# https://www.comics.org/issue/48681/
# https://www.comics.org/issue/48797/
# https://www.comics.org/issue/49075/
# https://www.comics.org/issue/49194/
# https://www.comics.org/issue/49316/
# https://www.comics.org/issue/49435/
# https://www.comics.org/issue/49553/
# https://www.comics.org/issue/49668/
# https://www.comics.org/issue/49786/
# https://www.comics.org/issue/49922/
# https://www.comics.org/issue/50046/
# https://www.comics.org/issue/50183/
# https://www.comics.org/issue/50312/
# https://www.comics.org/issue/50442/
# https://www.comics.org/issue/50733/
# https://www.comics.org/issue/50851/
# https://www.comics.org/issue/50977/
# https://www.comics.org/issue/51085/
# https://www.comics.org/issue/51207/
# https://www.comics.org/issue/51320/
# https://www.comics.org/issue/51456/
# https://www.comics.org/issue/51589/
# https://www.comics.org/issue/51727/
# https://www.comics.org/issue/51858/
# https://www.comics.org/issue/51998/
# https://www.comics.org/issue/52132/
# https://www.comics.org/issue/52403/
# https://www.comics.org/issue/52528/
# https://www.comics.org/issue/52646/
# https://www.comics.org/issue/52778/
# https://www.comics.org/issue/52924/
# https://www.comics.org/issue/53077/
# https://www.comics.org/issue/53251/
# https://www.comics.org/issue/53414/
# https://www.comics.org/issue/53566/
# https://www.comics.org/issue/53732/
# https://www.comics.org/issue/53900/
# https://www.comics.org/issue/54075/
# https://www.comics.org/issue/54345/
# https://www.comics.org/issue/54514/
# https://www.comics.org/issue/54675/
# https://www.comics.org/issue/54844/
# https://www.comics.org/issue/55005/
# https://www.comics.org/issue/55159/
# https://www.comics.org/issue/55323/
# https://www.comics.org/issue/55475/
# https://www.comics.org/issue/55629/
# https://www.comics.org/issue/55794/
# https://www.comics.org/issue/55952/
# https://www.comics.org/issue/56105/
# https://www.comics.org/issue/56371/
# https://www.comics.org/issue/56532/
# https://www.comics.org/issue/56688/
# https://www.comics.org/issue/56843/
# https://www.comics.org/issue/56994/
# https://www.comics.org/issue/57137/
# https://www.comics.org/issue/57288/
# https://www.comics.org/issue/57451/
# https://www.comics.org/issue/57603/
# https://www.comics.org/issue/57757/
# https://www.comics.org/issue/57899/
# Animal Man /series/59310/ 30

# %%
get_all_from_publisher_page(publisher_url='https://www.comics.org/publisher/54/', page=4)
# Out:
# Animaniacs /series/14399/ 59
# https://www.comics.org/issue/249264/
# https://www.comics.org/issue/249265/
# https://www.comics.org/issue/1844242/
# https://www.comics.org/issue/249266/
# https://www.comics.org/issue/1540444/
# https://www.comics.org/issue/249267/
# https://www.comics.org/issue/249268/
# https://www.comics.org/issue/249269/
# https://www.comics.org/issue/249270/
# https://www.comics.org/issue/249271/
# https://www.comics.org/issue/1971955/
# https://www.comics.org/issue/1541115/
# https://www.comics.org/issue/249273/
# https://www.comics.org/issue/249274/
# https://www.comics.org/issue/1980066/
# https://www.comics.org/issue/249275/
# https://www.comics.org/issue/249276/
# https://www.comics.org/issue/249277/
# https://www.comics.org/issue/249278/
# https://www.comics.org/issue/249279/
# https://www.comics.org/issue/249280/
# https://www.comics.org/issue/249281/
# https://www.comics.org/issue/1811997/
# https://www.comics.org/issue/249282/
# https://www.comics.org/issue/249283/
# https://www.comics.org/issue/1979950/
# https://www.comics.org/issue/249284/
# https://www.comics.org/issue/1977130/
# https://www.comics.org/issue/249285/
# https://www.comics.org/issue/249286/
# https://www.comics.org/issue/249287/
# https://www.comics.org/issue/249288/
# https://www.comics.org/issue/249289/
# https://www.comics.org/issue/1541637/
# https://www.comics.org/issue/249290/
# https://www.comics.org/issue/249291/
# https://www.comics.org/issue/249292/
# https://www.comics.org/issue/249293/
# https://www.comics.org/issue/249294/
# https://www.comics.org/issue/1980458/
# https://www.comics.org/issue/249295/
# https://www.comics.org/issue/249296/
# https://www.comics.org/issue/876853/
# https://www.comics.org/issue/249297/
# https://www.comics.org/issue/876849/
# https://www.comics.org/issue/249298/
# https://www.comics.org/issue/876852/
# https://www.comics.org/issue/249299/
# https://www.comics.org/issue/1986002/
# https://www.comics.org/issue/249300/
# https://www.comics.org/issue/249301/
# https://www.comics.org/issue/249302/
# https://www.comics.org/issue/249303/
# https://www.comics.org/issue/249304/
# https://www.comics.org/issue/1986003/
# https://www.comics.org/issue/249305/
# https://www.comics.org/issue/249306/
# https://www.comics.org/issue/1542257/
# https://www.comics.org/issue/249307/
# https://www.comics.org/issue/249308/
# https://www.comics.org/issue/249309/
# https://www.comics.org/issue/249310/
# https://www.comics.org/issue/249311/
# https://www.comics.org/issue/249312/
# https://www.comics.org/issue/249313/
# https://www.comics.org/issue/249314/
# https://www.comics.org/issue/249315/
# https://www.comics.org/issue/249316/
# https://www.comics.org/issue/249317/
# https://www.comics.org/issue/249318/
# https://www.comics.org/issue/249319/
# https://www.comics.org/issue/249320/
# https://www.comics.org/issue/249321/
# https://www.comics.org/issue/249322/
# Aquaman /series/1488/ 63
# https://www.comics.org/issue/16699/
# https://www.comics.org/issue/16804/
# https://www.comics.org/issue/16903/
# https://www.comics.org/issue/17013/
# https://www.comics.org/issue/17124/
# https://www.comics.org/issue/17232/
# https://www.comics.org/issue/17425/
# https://www.comics.org/issue/17539/
# https://www.comics.org/issue/17635/
# https://www.comics.org/issue/17744/
# https://www.comics.org/issue/17856/
# https://www.comics.org/issue/17966/
# https://www.comics.org/issue/18148/
# https://www.comics.org/issue/18258/
# https://www.comics.org/issue/18357/
# https://www.comics.org/issue/18464/
# https://www.comics.org/issue/18587/
# https://www.comics.org/issue/18722/
# https://www.comics.org/issue/18870/
# https://www.comics.org/issue/19003/
# https://www.comics.org/issue/19135/
# https://www.comics.org/issue/19272/
# https://www.comics.org/issue/19422/
# https://www.comics.org/issue/19577/
# https://www.comics.org/issue/19745/
# https://www.comics.org/issue/19877/
# https://www.comics.org/issue/20017/
# https://www.comics.org/issue/20160/
# https://www.comics.org/issue/20308/
# https://www.comics.org/issue/20478/
# https://www.comics.org/issue/20649/
# https://www.comics.org/issue/20789/
# https://www.comics.org/issue/20950/
# https://www.comics.org/issue/21100/
# https://www.comics.org/issue/21246/
# https://www.comics.org/issue/21412/
# https://www.comics.org/issue/21566/
# https://www.comics.org/issue/21696/
# https://www.comics.org/issue/21838/
# https://www.comics.org/issue/21986/
# https://www.comics.org/issue/22138/
# https://www.comics.org/issue/22301/
# https://www.comics.org/issue/22441/
# https://www.comics.org/issue/22567/
# https://www.comics.org/issue/22697/
# https://www.comics.org/issue/22821/
# https://www.comics.org/issue/22938/
# https://www.comics.org/issue/23075/
# https://www.comics.org/issue/23210/
# https://www.comics.org/issue/23322/
# https://www.comics.org/issue/23438/
# https://www.comics.org/issue/23562/
# https://www.comics.org/issue/23690/
# https://www.comics.org/issue/23812/
# https://www.comics.org/issue/23949/
# https://www.comics.org/issue/24075/
# https://www.comics.org/issue/31283/
# https://www.comics.org/issue/31495/
# https://www.comics.org/issue/31689/
# https://www.comics.org/issue/31920/
# https://www.comics.org/issue/32098/
# https://www.comics.org/issue/32288/
# https://www.comics.org/issue/32470/
# Aquaman /series/4183/ 13
# Aquaman /series/4940/ 77
# https://www.comics.org/issue/55575/
# https://www.comics.org/issue/871027/
# https://www.comics.org/issue/55722/
# https://www.comics.org/issue/1663826/
# https://www.comics.org/issue/55888/
# https://www.comics.org/issue/56049/
# https://www.comics.org/issue/56209/
# https://www.comics.org/issue/56477/
# https://www.comics.org/issue/56626/
# https://www.comics.org/issue/56781/
# https://www.comics.org/issue/56938/
# https://www.comics.org/issue/2011375/
# https://www.comics.org/issue/57228/
# https://www.comics.org/issue/57382/
# https://www.comics.org/issue/57535/
# https://www.comics.org/issue/57687/
# https://www.comics.org/issue/57831/
# https://www.comics.org/issue/57974/
# https://www.comics.org/issue/58119/
# https://www.comics.org/issue/58362/
# https://www.comics.org/issue/58481/
# https://www.comics.org/issue/58602/
# https://www.comics.org/issue/58721/
# https://www.comics.org/issue/58825/
# https://www.comics.org/issue/58943/
# https://www.comics.org/issue/59063/
# https://www.comics.org/issue/59187/
# https://www.comics.org/issue/59297/
# https://www.comics.org/issue/59402/
# https://www.comics.org/issue/59512/
# https://www.comics.org/issue/59632/
# https://www.comics.org/issue/59850/
# https://www.comics.org/issue/59973/
# https://www.comics.org/issue/60082/
# https://www.comics.org/issue/60195/
# https://www.comics.org/issue/60312/
# https://www.comics.org/issue/60414/
# https://www.comics.org/issue/60536/
# https://www.comics.org/issue/60644/
# https://www.comics.org/issue/60772/
# https://www.comics.org/issue/60887/
# https://www.comics.org/issue/61013/
# https://www.comics.org/issue/61120/
# https://www.comics.org/issue/1987524/
# https://www.comics.org/issue/61324/
# https://www.comics.org/issue/61446/
# https://www.comics.org/issue/61551/
# https://www.comics.org/issue/61645/
# https://www.comics.org/issue/61740/
# https://www.comics.org/issue/61835/
# https://www.comics.org/issue/61926/
# https://www.comics.org/issue/62034/
# https://www.comics.org/issue/62143/
# https://www.comics.org/issue/62217/
# https://www.comics.org/issue/62296/
# https://www.comics.org/issue/62365/
# https://www.comics.org/issue/62464/
# https://www.comics.org/issue/62533/
# https://www.comics.org/issue/62598/
# https://www.comics.org/issue/62654/
# https://www.comics.org/issue/62705/
# https://www.comics.org/issue/62755/
# https://www.comics.org/issue/62804/
# https://www.comics.org/issue/62858/
# https://www.comics.org/issue/62910/
# https://www.comics.org/issue/62957/
# https://www.comics.org/issue/63006/
# https://www.comics.org/issue/63052/
# https://www.comics.org/issue/63120/
# https://www.comics.org/issue/63169/
# https://www.comics.org/issue/63219/
# https://www.comics.org/issue/63249/
# https://www.comics.org/issue/63288/
# https://www.comics.org/issue/63310/
# https://www.comics.org/issue/63328/
# https://www.comics.org/issue/63344/
# https://www.comics.org/issue/63364/
# https://www.comics.org/issue/65358/
# https://www.comics.org/issue/65359/
# https://www.comics.org/issue/65360/
# https://www.comics.org/issue/65361/
# Aquaman /series/10315/ 39
# Aquaman /series/61178/ 55
# https://www.comics.org/issue/879924/
# https://www.comics.org/issue/903469/
# https://www.comics.org/issue/888594/
# https://www.comics.org/issue/898417/
# https://www.comics.org/issue/902654/
# https://www.comics.org/issue/906572/
# https://www.comics.org/issue/916752/
# https://www.comics.org/issue/922442/
# https://www.comics.org/issue/942048/
# https://www.comics.org/issue/933289/
# https://www.comics.org/issue/941099/
# https://www.comics.org/issue/1198647/
# https://www.comics.org/issue/946672/
# https://www.comics.org/issue/1198648/
# https://www.comics.org/issue/954228/
# https://www.comics.org/issue/1198649/
# https://www.comics.org/issue/974068/
# https://www.comics.org/issue/1198650/
# https://www.comics.org/issue/996601/
# https://www.comics.org/issue/1030073/
# https://www.comics.org/issue/1030072/
# https://www.comics.org/issue/1010721/
# https://www.comics.org/issue/1198651/
# https://www.comics.org/issue/1028939/
# https://www.comics.org/issue/1036001/
# https://www.comics.org/issue/1198656/
# https://www.comics.org/issue/1040808/
# https://www.comics.org/issue/1198652/
# https://www.comics.org/issue/1087247/
# https://www.comics.org/issue/1198770/
# https://www.comics.org/issue/1096337/
# https://www.comics.org/issue/1060915/
# https://www.comics.org/issue/1198653/
# https://www.comics.org/issue/1198730/
# https://www.comics.org/issue/1087028/
# https://www.comics.org/issue/1198654/
# https://www.comics.org/issue/1096678/
# https://www.comics.org/issue/1096709/
# https://www.comics.org/issue/1157641/
# https://www.comics.org/issue/1108044/
# https://www.comics.org/issue/1125327/
# https://www.comics.org/issue/1115029/
# https://www.comics.org/issue/1198644/
# https://www.comics.org/issue/1123912/
# https://www.comics.org/issue/1198728/
# https://www.comics.org/issue/1129390/
# https://www.comics.org/issue/1131268/
# https://www.comics.org/issue/1198531/
# https://www.comics.org/issue/1139335/
# https://www.comics.org/issue/1198657/
# https://www.comics.org/issue/1140826/
# https://www.comics.org/issue/1149135/
# https://www.comics.org/issue/1142498/
# https://www.comics.org/issue/1158509/
# https://www.comics.org/issue/1149493/
# https://www.comics.org/issue/1198309/
# https://www.comics.org/issue/1164918/
# https://www.comics.org/issue/1198729/
# https://www.comics.org/issue/1198532/
# https://www.comics.org/issue/1171975/
# https://www.comics.org/issue/1198658/
# https://www.comics.org/issue/1198534/
# https://www.comics.org/issue/1175499/
# https://www.comics.org/issue/1198659/
# https://www.comics.org/issue/1196321/
# https://www.comics.org/issue/1182807/
# https://www.comics.org/issue/1198514/
# https://www.comics.org/issue/1192634/
# https://www.comics.org/issue/1243313/
# https://www.comics.org/issue/1198468/
# https://www.comics.org/issue/1243495/
# https://www.comics.org/issue/1208381/
# https://www.comics.org/issue/1243508/
# https://www.comics.org/issue/1216103/
# https://www.comics.org/issue/1243314/
# https://www.comics.org/issue/1244809/
# https://www.comics.org/issue/1245457/
# https://www.comics.org/issue/1248237/
# https://www.comics.org/issue/1248589/
# https://www.comics.org/issue/1265451/
# https://www.comics.org/issue/1267628/
# https://www.comics.org/issue/1284463/
# https://www.comics.org/issue/1285235/
# https://www.comics.org/issue/1297000/
# https://www.comics.org/issue/1297448/
# https://www.comics.org/issue/1310220/
# https://www.comics.org/issue/1313209/
# https://www.comics.org/issue/1325038/
# https://www.comics.org/issue/1492560/
# https://www.comics.org/issue/1331960/
# https://www.comics.org/issue/1492561/
# https://www.comics.org/issue/1429090/
# https://www.comics.org/issue/1431019/
# https://www.comics.org/issue/1438486/
# https://www.comics.org/issue/1443963/
# https://www.comics.org/issue/1450249/
# https://www.comics.org/issue/1452868/
# https://www.comics.org/issue/1462095/
# https://www.comics.org/issue/1484979/
# https://www.comics.org/issue/1491645/
# https://www.comics.org/issue/1503708/
# https://www.comics.org/issue/1509542/
# https://www.comics.org/issue/1514266/
# https://www.comics.org/issue/1527906/
# https://www.comics.org/issue/1529355/
# https://www.comics.org/issue/1540349/
# https://www.comics.org/issue/1542700/
# https://www.comics.org/issue/1549584/
# https://www.comics.org/issue/1554140/
# https://www.comics.org/issue/1559090/
# https://www.comics.org/issue/1563637/
# https://www.comics.org/issue/1571441/
# Aquaman /series/103459/ 53
# https://www.comics.org/issue/1583742/
# https://www.comics.org/issue/1591238/
# https://www.comics.org/issue/1661438/
# https://www.comics.org/issue/1599813/
# https://www.comics.org/issue/1602189/
# https://www.comics.org/issue/1604112/
# https://www.comics.org/issue/1605600/
# https://www.comics.org/issue/1608164/
# https://www.comics.org/issue/1613448/
# https://www.comics.org/issue/1615978/
# https://www.comics.org/issue/1617502/
# https://www.comics.org/issue/1620539/
# https://www.comics.org/issue/1621773/
# https://www.comics.org/issue/1624191/
# https://www.comics.org/issue/1625883/
# https://www.comics.org/issue/1635274/
# https://www.comics.org/issue/1637270/
# https://www.comics.org/issue/1639209/
# https://www.comics.org/issue/1640606/
# https://www.comics.org/issue/1642968/
# https://www.comics.org/issue/1648265/
# https://www.comics.org/issue/1649463/
# https://www.comics.org/issue/1652912/
# https://www.comics.org/issue/1657190/
# https://www.comics.org/issue/1658236/
# https://www.comics.org/issue/1660178/
# https://www.comics.org/issue/1661218/
# https://www.comics.org/issue/1663314/
# https://www.comics.org/issue/1664671/
# https://www.comics.org/issue/1667221/
# https://www.comics.org/issue/1668969/
# https://www.comics.org/issue/1671809/
# https://www.comics.org/issue/1673142/
# https://www.comics.org/issue/1675075/
# https://www.comics.org/issue/1675888/
# https://www.comics.org/issue/1677317/
# https://www.comics.org/issue/1678869/
# https://www.comics.org/issue/1680358/
# https://www.comics.org/issue/1682412/
# https://www.comics.org/issue/1688628/
# https://www.comics.org/issue/1690581/
# https://www.comics.org/issue/1692365/
# https://www.comics.org/issue/1693364/
# https://www.comics.org/issue/1696182/
# https://www.comics.org/issue/1697596/
# https://www.comics.org/issue/1699911/
# https://www.comics.org/issue/1704710/
# https://www.comics.org/issue/1709847/
# https://www.comics.org/issue/1710064/
# https://www.comics.org/issue/1716886/
# https://www.comics.org/issue/1718514/
# https://www.comics.org/issue/1722597/
# https://www.comics.org/issue/1723033/
# https://www.comics.org/issue/1728015/
# https://www.comics.org/issue/1728679/
# https://www.comics.org/issue/1735429/
# https://www.comics.org/issue/1736837/
# https://www.comics.org/issue/1746450/
# https://www.comics.org/issue/1744028/
# https://www.comics.org/issue/1744232/
# https://www.comics.org/issue/1757686/
# https://www.comics.org/issue/1760279/
# https://www.comics.org/issue/1769701/
# https://www.comics.org/issue/1771059/
# https://www.comics.org/issue/1776084/
# https://www.comics.org/issue/1777678/
# https://www.comics.org/issue/1787507/
# https://www.comics.org/issue/1788447/
# https://www.comics.org/issue/1793006/
# https://www.comics.org/issue/1796190/
# https://www.comics.org/issue/1800667/
# https://www.comics.org/issue/1800756/
# https://www.comics.org/issue/1808291/
# https://www.comics.org/issue/1809219/
# https://www.comics.org/issue/1818255/
# https://www.comics.org/issue/1820695/
# https://www.comics.org/issue/1826862/
# https://www.comics.org/issue/1830478/
# https://www.comics.org/issue/1836080/
# https://www.comics.org/issue/1838157/
# https://www.comics.org/issue/1849170/
# https://www.comics.org/issue/1850909/
# https://www.comics.org/issue/1858433/
# https://www.comics.org/issue/1859810/
# https://www.comics.org/issue/1875077/
# https://www.comics.org/issue/1876175/
# https://www.comics.org/issue/1884022/
# https://www.comics.org/issue/1885778/
# https://www.comics.org/issue/1908449/
# https://www.comics.org/issue/1914141/
# https://www.comics.org/issue/1925520/
# https://www.comics.org/issue/1928063/
# https://www.comics.org/issue/1938946/
# https://www.comics.org/issue/1941483/
# https://www.comics.org/issue/1949956/
# https://www.comics.org/issue/1952284/
# https://www.comics.org/issue/1963144/
# https://www.comics.org/issue/1964957/
# https://www.comics.org/issue/1978131/
# https://www.comics.org/issue/1997142/
# https://www.comics.org/issue/2010090/
# https://www.comics.org/issue/2016009/
# https://www.comics.org/issue/2024437/
# Aquaman: Sword of Atlantis /series/15946/ 18
# Arak / Son of Thunder /series/2584/ 50
# https://www.comics.org/issue/35607/
# https://www.comics.org/issue/1127265/
# https://www.comics.org/issue/35690/
# https://www.comics.org/issue/1096632/
# https://www.comics.org/issue/35772/
# https://www.comics.org/issue/35843/
# https://www.comics.org/issue/1687725/
# https://www.comics.org/issue/35983/
# https://www.comics.org/issue/1687660/
# https://www.comics.org/issue/36061/
# https://www.comics.org/issue/1687640/
# https://www.comics.org/issue/36152/
# https://www.comics.org/issue/1687581/
# https://www.comics.org/issue/36236/
# https://www.comics.org/issue/1304950/
# https://www.comics.org/issue/36321/
# https://www.comics.org/issue/1304905/
# https://www.comics.org/issue/36397/
# https://www.comics.org/issue/1304948/
# https://www.comics.org/issue/36478/
# https://www.comics.org/issue/1687361/
# https://www.comics.org/issue/36554/
# https://www.comics.org/issue/1687348/
# https://www.comics.org/issue/36634/
# https://www.comics.org/issue/1687289/
# https://www.comics.org/issue/36711/
# https://www.comics.org/issue/1687209/
# https://www.comics.org/issue/1832129/
# https://www.comics.org/issue/36793/
# https://www.comics.org/issue/1687085/
# https://www.comics.org/issue/1727570/
# https://www.comics.org/issue/36876/
# https://www.comics.org/issue/1685427/
# https://www.comics.org/issue/37009/
# https://www.comics.org/issue/1685311/
# https://www.comics.org/issue/37088/
# https://www.comics.org/issue/1030804/
# https://www.comics.org/issue/1110586/
# https://www.comics.org/issue/37183/
# https://www.comics.org/issue/1037222/
# https://www.comics.org/issue/1110588/
# https://www.comics.org/issue/37268/
# https://www.comics.org/issue/1048904/
# https://www.comics.org/issue/1110584/
# https://www.comics.org/issue/37365/
# https://www.comics.org/issue/1061011/
# https://www.comics.org/issue/1110585/
# https://www.comics.org/issue/37458/
# https://www.comics.org/issue/1110587/
# https://www.comics.org/issue/37550/
# https://www.comics.org/issue/1095367/
# https://www.comics.org/issue/1111064/
# https://www.comics.org/issue/37639/
# https://www.comics.org/issue/1101472/
# https://www.comics.org/issue/1111066/
# https://www.comics.org/issue/37725/
# https://www.comics.org/issue/1119855/
# https://www.comics.org/issue/1111074/
# https://www.comics.org/issue/37814/
# https://www.comics.org/issue/1121383/
# https://www.comics.org/issue/1111091/
# https://www.comics.org/issue/37901/
# https://www.comics.org/issue/1124134/
# https://www.comics.org/issue/1111092/
# https://www.comics.org/issue/38008/
# https://www.comics.org/issue/1127462/
# https://www.comics.org/issue/1108699/
# https://www.comics.org/issue/38160/
# https://www.comics.org/issue/1096628/
# https://www.comics.org/issue/1111593/
# https://www.comics.org/issue/38270/
# https://www.comics.org/issue/1096633/
# https://www.comics.org/issue/1111594/
# https://www.comics.org/issue/38391/
# https://www.comics.org/issue/1136836/
# https://www.comics.org/issue/1111651/
# https://www.comics.org/issue/38506/
# https://www.comics.org/issue/1111652/
# https://www.comics.org/issue/1137545/
# https://www.comics.org/issue/38616/
# https://www.comics.org/issue/1137703/
# https://www.comics.org/issue/1112675/
# https://www.comics.org/issue/38724/
# https://www.comics.org/issue/1138525/
# https://www.comics.org/issue/1112676/
# https://www.comics.org/issue/38834/
# https://www.comics.org/issue/1139008/
# https://www.comics.org/issue/1112723/
# https://www.comics.org/issue/38937/
# https://www.comics.org/issue/1139022/
# https://www.comics.org/issue/1114482/
# https://www.comics.org/issue/39050/
# https://www.comics.org/issue/1139268/
# https://www.comics.org/issue/1114485/
# https://www.comics.org/issue/39245/
# https://www.comics.org/issue/1114514/
# https://www.comics.org/issue/39356/
# https://www.comics.org/issue/1114627/
# https://www.comics.org/issue/39540/
# https://www.comics.org/issue/1114953/
# https://www.comics.org/issue/39634/
# https://www.comics.org/issue/1114954/
# https://www.comics.org/issue/39739/
# https://www.comics.org/issue/1115194/
# https://www.comics.org/issue/39835/
# https://www.comics.org/issue/1115220/
# https://www.comics.org/issue/39952/
# https://www.comics.org/issue/40051/
# https://www.comics.org/issue/1115579/
# https://www.comics.org/issue/1725283/
# https://www.comics.org/issue/40166/
# https://www.comics.org/issue/1681354/
# https://www.comics.org/issue/40269/
# https://www.comics.org/issue/1684929/
# https://www.comics.org/issue/1762678/
# https://www.comics.org/issue/40377/
# https://www.comics.org/issue/1762679/
# https://www.comics.org/issue/40480/
# https://www.comics.org/issue/1762680/
# https://www.comics.org/issue/40596/
# https://www.comics.org/issue/1685240/
# https://www.comics.org/issue/1762681/
# Arion, Lord of Atlantis /series/2620/ 35
# https://www.comics.org/issue/36794/
# https://www.comics.org/issue/1466176/
# https://www.comics.org/issue/1800535/
# https://www.comics.org/issue/36877/
# https://www.comics.org/issue/1146616/
# https://www.comics.org/issue/1772558/
# https://www.comics.org/issue/37010/
# https://www.comics.org/issue/1466175/
# https://www.comics.org/issue/37089/
# https://www.comics.org/issue/1036551/
# https://www.comics.org/issue/1704831/
# https://www.comics.org/issue/37184/
# https://www.comics.org/issue/1040287/
# https://www.comics.org/issue/1772559/
# https://www.comics.org/issue/37269/
# https://www.comics.org/issue/1052984/
# https://www.comics.org/issue/1880134/
# https://www.comics.org/issue/37366/
# https://www.comics.org/issue/1087070/
# https://www.comics.org/issue/1772560/
# https://www.comics.org/issue/37459/
# https://www.comics.org/issue/1095247/
# https://www.comics.org/issue/1772561/
# https://www.comics.org/issue/37551/
# https://www.comics.org/issue/1099092/
# https://www.comics.org/issue/1772566/
# https://www.comics.org/issue/37640/
# https://www.comics.org/issue/1115654/
# https://www.comics.org/issue/1772562/
# https://www.comics.org/issue/37726/
# https://www.comics.org/issue/1096631/
# https://www.comics.org/issue/37815/
# https://www.comics.org/issue/1124124/
# https://www.comics.org/issue/37902/
# https://www.comics.org/issue/1126201/
# https://www.comics.org/issue/38009/
# https://www.comics.org/issue/1466147/
# https://www.comics.org/issue/38161/
# https://www.comics.org/issue/1131562/
# https://www.comics.org/issue/1800532/
# https://www.comics.org/issue/38271/
# https://www.comics.org/issue/1134068/
# https://www.comics.org/issue/38392/
# https://www.comics.org/issue/1137226/
# https://www.comics.org/issue/1800533/
# https://www.comics.org/issue/38507/
# https://www.comics.org/issue/1137553/
# https://www.comics.org/issue/1800534/
# https://www.comics.org/issue/38617/
# https://www.comics.org/issue/1137735/
# https://www.comics.org/issue/1800559/
# https://www.comics.org/issue/38725/
# https://www.comics.org/issue/1138901/
# https://www.comics.org/issue/1772563/
# https://www.comics.org/issue/38835/
# https://www.comics.org/issue/1139016/
# https://www.comics.org/issue/1800560/
# https://www.comics.org/issue/38938/
# https://www.comics.org/issue/1139258/
# https://www.comics.org/issue/1772571/
# https://www.comics.org/issue/39051/
# https://www.comics.org/issue/1139274/
# https://www.comics.org/issue/953394/
# https://www.comics.org/issue/39143/
# https://www.comics.org/issue/1139513/
# https://www.comics.org/issue/1762677/
# https://www.comics.org/issue/39246/
# https://www.comics.org/issue/1139529/
# https://www.comics.org/issue/1139590/
# https://www.comics.org/issue/39357/
# https://www.comics.org/issue/1437650/
# https://www.comics.org/issue/1437653/
# https://www.comics.org/issue/39541/
# https://www.comics.org/issue/1437677/
# https://www.comics.org/issue/1437681/
# https://www.comics.org/issue/39635/
# https://www.comics.org/issue/1466281/
# https://www.comics.org/issue/1721916/
# https://www.comics.org/issue/39740/
# https://www.comics.org/issue/1466283/
# https://www.comics.org/issue/1704838/
# https://www.comics.org/issue/39836/
# https://www.comics.org/issue/1466280/
# https://www.comics.org/issue/1704840/
# https://www.comics.org/issue/39953/
# https://www.comics.org/issue/1466279/
# https://www.comics.org/issue/1722170/
# https://www.comics.org/issue/40052/
# https://www.comics.org/issue/1466277/
# https://www.comics.org/issue/1722171/
# https://www.comics.org/issue/40167/
# https://www.comics.org/issue/1466278/
# https://www.comics.org/issue/1722168/
# https://www.comics.org/issue/40270/
# https://www.comics.org/issue/1466276/
# https://www.comics.org/issue/1722169/
# https://www.comics.org/issue/40378/
# https://www.comics.org/issue/1466275/
# Army@Love /series/23429/ 12
# Arrow /series/70165/ 12
# Arrow Season 2.5 /series/83433/ 12

# %%
get_all_from_publisher_page(publisher_url='https://www.comics.org/publisher/54/', page=5)
# Out:
# Art Ops /series/93356/ 12
# Astro City /series/74788/ 52
# https://www.comics.org/issue/1119068/
# https://www.comics.org/issue/1142945/
# https://www.comics.org/issue/1127335/
# https://www.comics.org/issue/1136759/
# https://www.comics.org/issue/1140832/
# https://www.comics.org/issue/1145504/
# https://www.comics.org/issue/1158648/
# https://www.comics.org/issue/1168285/
# https://www.comics.org/issue/1173527/
# https://www.comics.org/issue/1179220/
# https://www.comics.org/issue/1186388/
# https://www.comics.org/issue/1196969/
# https://www.comics.org/issue/1206036/
# https://www.comics.org/issue/1212824/
# https://www.comics.org/issue/1246738/
# https://www.comics.org/issue/1251362/
# https://www.comics.org/issue/1261780/
# https://www.comics.org/issue/1281095/
# https://www.comics.org/issue/1288560/
# https://www.comics.org/issue/1304992/
# https://www.comics.org/issue/1318736/
# https://www.comics.org/issue/1328030/
# https://www.comics.org/issue/1338542/
# https://www.comics.org/issue/1353467/
# https://www.comics.org/issue/1420659/
# https://www.comics.org/issue/1435696/
# https://www.comics.org/issue/1448708/
# https://www.comics.org/issue/1460481/
# https://www.comics.org/issue/1478488/
# https://www.comics.org/issue/1499599/
# https://www.comics.org/issue/1514269/
# https://www.comics.org/issue/1526377/
# https://www.comics.org/issue/1537660/
# https://www.comics.org/issue/1546548/
# https://www.comics.org/issue/1559098/
# https://www.comics.org/issue/1571442/
# https://www.comics.org/issue/1581814/
# https://www.comics.org/issue/1604109/
# https://www.comics.org/issue/1621988/
# https://www.comics.org/issue/1628467/
# https://www.comics.org/issue/1639205/
# https://www.comics.org/issue/1676247/
# https://www.comics.org/issue/1677063/
# https://www.comics.org/issue/1679023/
# https://www.comics.org/issue/1692366/
# https://www.comics.org/issue/1699908/
# https://www.comics.org/issue/1718607/
# https://www.comics.org/issue/1728016/
# https://www.comics.org/issue/1732333/
# https://www.comics.org/issue/1744029/
# https://www.comics.org/issue/1760957/
# https://www.comics.org/issue/1778740/
# https://www.comics.org/issue/1797709/
# https://www.comics.org/issue/1820450/
# Atari Force /series/2829/ 20
# https://www.comics.org/issue/38162/
# https://www.comics.org/issue/1131259/
# https://www.comics.org/issue/1917562/
# https://www.comics.org/issue/38272/
# https://www.comics.org/issue/1131555/
# https://www.comics.org/issue/1800346/
# https://www.comics.org/issue/38393/
# https://www.comics.org/issue/1133205/
# https://www.comics.org/issue/1800348/
# https://www.comics.org/issue/38508/
# https://www.comics.org/issue/1133217/
# https://www.comics.org/issue/1800347/
# https://www.comics.org/issue/38618/
# https://www.comics.org/issue/1133218/
# https://www.comics.org/issue/1800350/
# https://www.comics.org/issue/38726/
# https://www.comics.org/issue/1133219/
# https://www.comics.org/issue/1800349/
# https://www.comics.org/issue/38836/
# https://www.comics.org/issue/1133220/
# https://www.comics.org/issue/1800351/
# https://www.comics.org/issue/38939/
# https://www.comics.org/issue/1133221/
# https://www.comics.org/issue/1702608/
# https://www.comics.org/issue/39052/
# https://www.comics.org/issue/1133222/
# https://www.comics.org/issue/1762682/
# https://www.comics.org/issue/39144/
# https://www.comics.org/issue/1133223/
# https://www.comics.org/issue/1762683/
# https://www.comics.org/issue/39247/
# https://www.comics.org/issue/1133224/
# https://www.comics.org/issue/1762684/
# https://www.comics.org/issue/39358/
# https://www.comics.org/issue/1133225/
# https://www.comics.org/issue/1702609/
# https://www.comics.org/issue/39543/
# https://www.comics.org/issue/1133226/
# https://www.comics.org/issue/1702610/
# https://www.comics.org/issue/39636/
# https://www.comics.org/issue/1131246/
# https://www.comics.org/issue/1702611/
# https://www.comics.org/issue/39741/
# https://www.comics.org/issue/1133227/
# https://www.comics.org/issue/1702612/
# https://www.comics.org/issue/39837/
# https://www.comics.org/issue/1133228/
# https://www.comics.org/issue/1762685/
# https://www.comics.org/issue/39954/
# https://www.comics.org/issue/1133250/
# https://www.comics.org/issue/1762686/
# https://www.comics.org/issue/40053/
# https://www.comics.org/issue/1681140/
# https://www.comics.org/issue/1762687/
# https://www.comics.org/issue/40168/
# https://www.comics.org/issue/1681266/
# https://www.comics.org/issue/1702613/
# https://www.comics.org/issue/40271/
# https://www.comics.org/issue/1684930/
# https://www.comics.org/issue/1762688/
# The Atom /series/1489/ 38
# The Authority /series/8099/ 29
# The Authority /series/12141/ 15
# The Authority /series/31874/ 29
# The Authority: Revolution /series/12144/ 12
# Azrael /series/5220/ 47
# https://www.comics.org/issue/56533/
# https://www.comics.org/issue/56689/
# https://www.comics.org/issue/1972638/
# https://www.comics.org/issue/56845/
# https://www.comics.org/issue/56995/
# https://www.comics.org/issue/855629/
# https://www.comics.org/issue/57139/
# https://www.comics.org/issue/57290/
# https://www.comics.org/issue/57453/
# https://www.comics.org/issue/57605/
# https://www.comics.org/issue/57759/
# https://www.comics.org/issue/57900/
# https://www.comics.org/issue/58047/
# https://www.comics.org/issue/58296/
# https://www.comics.org/issue/1945100/
# https://www.comics.org/issue/58421/
# https://www.comics.org/issue/128259/
# https://www.comics.org/issue/128260/
# https://www.comics.org/issue/1980505/
# https://www.comics.org/issue/128261/
# https://www.comics.org/issue/58770/
# https://www.comics.org/issue/58877/
# https://www.comics.org/issue/59004/
# https://www.comics.org/issue/59123/
# https://www.comics.org/issue/59242/
# https://www.comics.org/issue/59344/
# https://www.comics.org/issue/59451/
# https://www.comics.org/issue/59558/
# https://www.comics.org/issue/59784/
# https://www.comics.org/issue/128262/
# https://www.comics.org/issue/128263/
# https://www.comics.org/issue/128264/
# https://www.comics.org/issue/128265/
# https://www.comics.org/issue/128266/
# https://www.comics.org/issue/134108/
# https://www.comics.org/issue/134109/
# https://www.comics.org/issue/134110/
# https://www.comics.org/issue/134111/
# https://www.comics.org/issue/134112/
# https://www.comics.org/issue/134113/
# https://www.comics.org/issue/134114/
# https://www.comics.org/issue/134115/
# https://www.comics.org/issue/134116/
# https://www.comics.org/issue/134117/
# https://www.comics.org/issue/134118/
# https://www.comics.org/issue/134119/
# https://www.comics.org/issue/134120/
# https://www.comics.org/issue/134121/
# https://www.comics.org/issue/134122/
# https://www.comics.org/issue/134123/
# https://www.comics.org/issue/246949/
# Azrael /series/39888/ 18
# Azrael: Agent of the Bat /series/13575/ 54
# https://www.comics.org/issue/243227/
# https://www.comics.org/issue/243228/
# https://www.comics.org/issue/243229/
# https://www.comics.org/issue/243230/
# https://www.comics.org/issue/243231/
# https://www.comics.org/issue/243232/
# https://www.comics.org/issue/243233/
# https://www.comics.org/issue/243234/
# https://www.comics.org/issue/243235/
# https://www.comics.org/issue/243236/
# https://www.comics.org/issue/243237/
# https://www.comics.org/issue/243238/
# https://www.comics.org/issue/243239/
# https://www.comics.org/issue/243240/
# https://www.comics.org/issue/243241/
# https://www.comics.org/issue/243242/
# https://www.comics.org/issue/243243/
# https://www.comics.org/issue/243244/
# https://www.comics.org/issue/243245/
# https://www.comics.org/issue/243246/
# https://www.comics.org/issue/243247/
# https://www.comics.org/issue/243248/
# https://www.comics.org/issue/243249/
# https://www.comics.org/issue/243250/
# https://www.comics.org/issue/243251/
# https://www.comics.org/issue/243252/
# https://www.comics.org/issue/243253/
# https://www.comics.org/issue/243254/
# https://www.comics.org/issue/243255/
# https://www.comics.org/issue/243256/
# https://www.comics.org/issue/243257/
# https://www.comics.org/issue/243258/
# https://www.comics.org/issue/243259/
# https://www.comics.org/issue/243260/
# https://www.comics.org/issue/243261/
# https://www.comics.org/issue/243262/
# https://www.comics.org/issue/243263/
# https://www.comics.org/issue/243264/
# https://www.comics.org/issue/243265/
# https://www.comics.org/issue/243266/
# https://www.comics.org/issue/243267/
# https://www.comics.org/issue/243268/
# https://www.comics.org/issue/243269/
# https://www.comics.org/issue/243270/
# https://www.comics.org/issue/243271/
# https://www.comics.org/issue/243272/
# https://www.comics.org/issue/243273/
# https://www.comics.org/issue/243274/

# %%
# # TODO: load metadata and return aggregate / summary statistics
# # TODO: write method to display cover image w/ cover metadata and add annotations to image
# # TODO: consider ideate/innotater for annotating directly in Jupyter notebooks

logged_metadata = []

with jsonlines.open('./metadata/covers.jsonl', mode='r') as reader:
    for item in reader:
        logged_metadata.append(item)
        
df = pd.DataFrame(logged_metadata)

# %%
def get_issue_number_from_title(title):
    issue = re.search(r"([#?])(\d+)\b", title.replace(',', ''))
    if issue is None:
        return np.nan
    else:
        return np.int(issue.group().replace('#', ''))

df['issue_number'] = df['title'].apply(get_issue_number_from_title)

df.drop('issue_number', axis=1).describe().T
# Out:
#                                      count unique  \
# cover_characters                      2333   1324
# cover_colors                          2711    189
# cover_editing                           47      4
# cover_first line of dialogue or text   277    277
# cover_genre                           2681     29
# cover_image_file_name                 2770   2770
# cover_inks                            2712    481
# cover_job number                       312    311
# cover_keywords                         781    594
# cover_letters                         2350     37
# cover_pencils                         2713    471
# cover_script                           393     18
# cover_synopsis                          23     23
# format_binding                        2770      9
# format_color                          2770      2
# format_dimensions                     2770     16
# format_paper_stock                    2770      9
# format_publishing_format              2770     11
# indexer_notes                         2770   2148
# indicia_frequency                     2770     59
# issue_brand                           2770     26
# issue_indicia_publisher               2770     12
# issue_pages                           2770     29
# issue_price                           2770    108
# on_sale_date                          2770   2147
# rating                                2770      7
# series_name                           2770     29
# synopsis                              2770   2194
# title                                 2770   2770
#
#                                                                                     top  \
# cover_characters                                                               Superman
# cover_colors                                                                          ?
# cover_editing                                         Robert Greenberger (cover editor)
# cover_first line of dialogue or text              A little more off the bottom, please!
# cover_genre                                                                   superhero
# cover_image_file_name                 Adventures of Superman -- Adventures of Superm...
# cover_inks                                                                    Stan Kaye
# cover_job number                                                                  C-422
# cover_keywords                                                                celebrity
# cover_letters                                                                         ?
# cover_pencils                                                                 Curt Swan
# cover_script                                                                          ?
# cover_synopsis                                                      Man fighting snake.
# format_binding                        saddle-stitched (squarebound #334, 347, 360, 3...
# format_color                                                                      color
# format_dimensions                     standard Golden Age US; then standard Silver A...
# format_paper_stock
# format_publishing_format                                             was ongoing series
# indexer_notes
# indicia_frequency                                                               monthly
# issue_brand                                                 Superman DC National Comics
# issue_indicia_publisher                                                       DC Comics
# issue_pages                                                                          36
# issue_price                                                                    0.10 USD
# on_sale_date
# rating                                            Approved by the Comics Code Authority
# series_name                                                               Action Comics
# synopsis
# title                                          The Adventures of Rex the Wonder Dog #25
#
#                                       freq
# cover_characters                       227
# cover_colors                          1721
# cover_editing                           33
# cover_first line of dialogue or text     1
# cover_genre                           1915
# cover_image_file_name                    1
# cover_inks                             220
# cover_job number                         2
# cover_keywords                          27
# cover_letters                         1654
# cover_pencils                          342
# cover_script                           367
# cover_synopsis                           1
# format_binding                         863
# format_color                          1604
# format_dimensions                      863
# format_paper_stock                    1449
# format_publishing_format              1619
# indexer_notes                          216
# indicia_frequency                     1832
# issue_brand                           1014
# issue_indicia_publisher                805
# issue_pages                           1793
# issue_price                            990
# on_sale_date                            34
# rating                                1604
# series_name                            928
# synopsis                               571
# title                                    1

# %%
# get list of unique characters across all  covers
def get_value_counts(df, column):
    """
    """
    return pd.Series("; ".join(df[column].dropna()).split('; ')).value_counts()

get_value_counts(df, 'cover_characters')[:20]
# Out:
# Superman                          635
# Kal-El]                           208
# Superman [Clark Kent              202
# Superman [Clark Kent]             186
# Lois Lane                         142
# Superboy                          123
# Bob Hope                          102
# Lex Luthor                         83
# Supergirl                          73
# Jerry Lewis                        60
# Superboy [Clark Kent]              52
# Doiby Dickles                      49
# Jimmy Olsen                        48
# The Green Lantern [Alan Scott]     39
# Saturn Girl                        36
# Lana Lang                          33
# Krypto                             30
# Green Lantern                      29
# Cosmic Boy                         29
# Agent Graves                       29
# dtype: int64

# %%
get_value_counts(df, 'cover_pencils')[:20]
# Out:
# Curt Swan                  349
# Bob Oksner                 113
# Gil Kane                    99
# Dave Johnson (signed)       91
# Win Mortimer                84
# Owen Fitzgerald             78
# Wayne Boring                68
# Jerry Grandenetti           59
# J. G. Jones (signed)        49
# Al Plastino                 49
# Ross Andru (signed)         48
# Jack Burnley                41
# Tom Grummett (signed)       37
# Neal Adams                  35
# Dan Jurgens (signed)        29
# Stuart Immonen (signed)     29
# Jerry Ordway (signed)       27
# Nick Cardy                  27
# Mort Drucker                21
# Irwin Hasen                 21
# dtype: int64

# %%
get_value_counts(df, 'series_name')[:20]
# Out:
# Action Comics                                  928
# Adventure Comics                               499
# Adventures of Superman                         241
# All-American Men of War                        116
# 100 Bullets                                    113
# The Adventures of Bob Hope                     109
# All-American Comics                            102
# All Star Western                                89
# The Adventures of Jerry Lewis                   84
# 80 Page Giant Magazine                          56
# 52                                              52
# The Adventures of Rex the Wonder Dog            46
# Action Comics Weekly                            42
# The Adventures of Dean Martin & Jerry Lewis     40
# Advanced Dungeons & Dragons Comic Book          36
# The All New Atom                                25
# Air                                             24
# All Funny Comics                                23
# Adventures in the DC Universe                   19
# All Star Batman                                 14
# dtype: int64

# %%
def concat_values_by_series(df, concat_column, series_name):    

    list_of_synopsis = df[
        (df['series_name'] == series_name) & df['issue_number'] != 0.0].sort_values('issue_number')[concat_column]

    return " | ".join(list_of_synopsis.values)

print(concat_values_by_series(df, concat_column='synopsis', series_name='Adventure Comics')[:2000], '...')
# Out:
# Conner settles into his new life, following in the footsteps of Superman -- living with Ma Kent, going to Smallville High, joining a team of super-heroes, and helping anyone who needs help -- but he worries that he will also follow the path of his other "father." | Though the Legion has almost fully re-formed in the future, Starman and Tellus remain in the present, where Starman begs Tellus to help him fulfill R. J. Brande's final request so he can be reunited with his one true love, Dream Girl. | As Luthor aids Brainiac in recovering Kandor, in exchange for the Earth, Superboy meets with Wonder Girl for the first time since his return. | Lightning Lord summons Lightning Lad and sends him on a quest to find a lost relative. | When Krypto rounds up some of Superboy’s old enemies, Conner wonders if Krypto can sniff out where Lex Luthor is.  When that doesn’t work, Superboy turns to Red Robin for help.  While the two catch up in Paris, the object of Superboy’s search discovers that the Teen of Steel has returned to the world of the living. | Polar Boy takes Sun Boy on a mission to his home planet of Tharr in search of minor league villain Cryo-King, but they discover that there may be more to Cryo-King than they thought. | After reading Adventure Comics #4, Superboy-Prime rushes to his comic book store to find out what happens to him in #5.  But while searching the internet there, he is attacked by Black Lantern Alexander Luthor, who brings with him Black Lanterns inhabiting the bodies of people Superboy-Prime killed. | Wildfire and Dawnstar accompany Blok to Sorcerer’s World to check on Mysa who has taken on Mordru’s power and is now the Black Witch. | Realizing his destiny is controlled by the people at DC Comics, Superboy-Prime tries to leave his fight with the Black Lanterns and take out his frustrations on the DC employees. But Black Lantern Alexander Luthor transports the Black Lanterns and Superboy-Prime to Prime's basement to continue the fight. Prime tries to  ...

# %%
df.describe().T
# Out:
#                                      count unique  \
# cover_characters                      2333   1324
# cover_colors                          2711    189
# cover_editing                           47      4
# cover_first line of dialogue or text   277    277
# cover_genre                           2681     29
# cover_image_file_name                 2770   2770
# cover_inks                            2712    481
# cover_job number                       312    311
# cover_keywords                         781    594
# cover_letters                         2350     37
# cover_pencils                         2713    471
# cover_script                           393     18
# cover_synopsis                          23     23
# format_binding                        2770      9
# format_color                          2770      2
# format_dimensions                     2770     16
# format_paper_stock                    2770      9
# format_publishing_format              2770     11
# indexer_notes                         2770   2148
# indicia_frequency                     2770     59
# issue_brand                           2770     26
# issue_indicia_publisher               2770     12
# issue_pages                           2770     29
# issue_price                           2770    108
# on_sale_date                          2770   2147
# rating                                2770      7
# series_name                           2770     29
# synopsis                              2770   2194
# title                                 2770   2770
#
#                                                                                     top  \
# cover_characters                                                               Superman
# cover_colors                                                                          ?
# cover_editing                                         Robert Greenberger (cover editor)
# cover_first line of dialogue or text              A little more off the bottom, please!
# cover_genre                                                                   superhero
# cover_image_file_name                 Adventures of Superman -- Adventures of Superm...
# cover_inks                                                                    Stan Kaye
# cover_job number                                                                  C-422
# cover_keywords                                                                celebrity
# cover_letters                                                                         ?
# cover_pencils                                                                 Curt Swan
# cover_script                                                                          ?
# cover_synopsis                                                      Man fighting snake.
# format_binding                        saddle-stitched (squarebound #334, 347, 360, 3...
# format_color                                                                      color
# format_dimensions                     standard Golden Age US; then standard Silver A...
# format_paper_stock
# format_publishing_format                                             was ongoing series
# indexer_notes
# indicia_frequency                                                               monthly
# issue_brand                                                 Superman DC National Comics
# issue_indicia_publisher                                                       DC Comics
# issue_pages                                                                          36
# issue_price                                                                    0.10 USD
# on_sale_date
# rating                                            Approved by the Comics Code Authority
# series_name                                                               Action Comics
# synopsis
# title                                          The Adventures of Rex the Wonder Dog #25
#
#                                       freq
# cover_characters                       227
# cover_colors                          1721
# cover_editing                           33
# cover_first line of dialogue or text     1
# cover_genre                           1915
# cover_image_file_name                    1
# cover_inks                             220
# cover_job number                         2
# cover_keywords                          27
# cover_letters                         1654
# cover_pencils                          342
# cover_script                           367
# cover_synopsis                           1
# format_binding                         863
# format_color                          1604
# format_dimensions                      863
# format_paper_stock                    1449
# format_publishing_format              1619
# indexer_notes                          216
# indicia_frequency                     1832
# issue_brand                           1014
# issue_indicia_publisher                805
# issue_pages                           1793
# issue_price                            990
# on_sale_date                            34
# rating                                1604
# series_name                            928
# synopsis                               571
# title                                    1

# %%
# dc US comics publisher page
url = 'https://www.comics.org/publisher/54/?page=1'

html = webscraper.simple_get(url)
soup = webscraper.transform_simple_get_html(html)

# %%
# parse series' metadata

name = soup.find_all('td', {'class': 'name'})
year = soup.find_all('td', {'class': 'year'})
issue_count = soup.find_all('td', {'class': 'issue_count'})
covers = soup.find_all('td', {'class': 'covers'})
published = soup.find_all('td', {'class': 'published'})

# %%
# TODO: get list of series names and urls from a publisher page (e.g. page=1)

n = [result.find('a').contents[0] for result in name]
href = [result.find('a')['href'] for result in  name]
y = [result.contents[0] for result in year]
i = [result.contents[0] for result in issue_count]
# c = [result.find('a').contents[0] for result in covers]
p = [result.contents[0] for result in published]

# %%
# TODO: reason about a series' metadata (# of issues, #  of covers)

# create series dataframe
series_df = pd.DataFrame(list(zip(n, href,  y, i, p)), columns=['name', 'href', 'year', 'issue_count', 'published'])

# parse issue count as int from issue_count  column
series_df['issue_count_int'] = series_df['issue_count'].apply(lambda x: int(re.search(r'\d+', x).group()))

# %%
series_df[series_df['issue_count_int'] > 12]
# Out:
#                       name            href  year               issue_count  \
# 3              100 Bullets   /series/6133/  1999  100 issues (100 indexed)
# 4              100 Bullets  /series/24535/  2000     13 issues (8 indexed)
# 16       1st Issue Special   /series/2212/  1975    13 issues (13 indexed)
# 22                      52  /series/16626/  2006    52 issues (52 indexed)
# 34  80 Page Giant Magazine   /series/1620/  1964    56 issues (15 indexed)
# 98           Action Comics     /series/97/  1938  866 issues (866 indexed)
# 99           Action Comics  /series/59922/  2011  117 issues (116 indexed)
#
#                             published  issue_count_int
# 3            August 1999 - April 2009              100
# 4        [January] 2000 - [July] 2009               13
# 16            April 1975 - April 1976               13
# 22              July 2006 - July 2007               52
# 34  August 1964 - February-March 1969               56
# 98           June 1938 - October 2011              866
# 99            November 2011 - Present              117

# %%
url = 'https://www.comics.org'
series_urls = url + series_df['href']

# take a series  with many issues...
series_page_url = series_urls[98]

series_page_html = webscraper.simple_get(series_page_url)
series_page_soup = webscraper.transform_simple_get_html(series_page_html)

# %%
# get 'series details cover gallery' url
cover_gallery_url = url + series_page_soup.find('a',  href=True, text='Cover Gallery')['href']

cover_gallery_html = webscraper.simple_get(cover_gallery_url)
cover_gallery_soup = webscraper.transform_simple_get_html(cover_gallery_html)

try:
    cover_gallery_pages = list(filter(lambda x: x.isdigit(), [x.contents[0] for x in cover_gallery_soup.find_all('a', {'class': "btn btn-default btn-sm"})]))
    cover_gallery_range = max([int(x) for x in cover_gallery_pages])

    for i in range(1, cover_gallery_range+1):
        cover_gallery_url = str(cover_gallery_url + '/?page={}').format(i)
        
except:
    continue

# %%
# # get issue hrefs from all linked issues on cover gallery
# issue_hrefs = list()
# for i in range(1, (84 + 1)):
#     if cover_gallery_soup.find('a',  href=True,  text=i) is not None:
#         issue_tag = cover_gallery_soup.find('a',  href=True,  text=i)
#         issue_hrefs.append(issue_hrefs.append(issue_tag['href']))
#         continue
#     elif cover_gallery_soup.find('a', href=True,  text='{} [Direct]'.format(i)) is not None:
#         issue_tag = cover_gallery_soup.find('a', href=True,  text='{} [Direct]'.format(i))
#         issue_hrefs.append(issue_hrefs.append(issue_tag['href']))
#         continue
#     else:
#         continue

# # filter out junk hrefs (I dunno... this is scraping... <shrug>)
# issue_hrefs = list(filter(lambda x: 'issue' in x, [i for i in issue_hrefs if i]))

# get issue hrefs from all linked issues on cover gallery
cover_gallery_hrefs = filter(lambda x: '/issue/' in x['href'] and '/cover/' not in x['href'], cover_gallery_soup.find_all('a',  href=True))
issue_hrefs = [x['href'] for x in cover_gallery_hrefs]

#  construct issue urls from issue hrefs
issue_urls = [url + issue_href for issue_href in  issue_hrefs]

# %%
issue_urls
# Out:
# ['https://www.comics.org/issue/552706/',
#  'https://www.comics.org/issue/625171/',
#  'https://www.comics.org/issue/873728/',
#  'https://www.comics.org/issue/625172/',
#  'https://www.comics.org/issue/875543/',
#  'https://www.comics.org/issue/625173/',
#  'https://www.comics.org/issue/875546/',
#  'https://www.comics.org/issue/671557/',
#  'https://www.comics.org/issue/875550/',
#  'https://www.comics.org/issue/680941/',
#  'https://www.comics.org/issue/875549/',
#  'https://www.comics.org/issue/703055/',
#  'https://www.comics.org/issue/875498/',
#  'https://www.comics.org/issue/716816/',
#  'https://www.comics.org/issue/875586/',
#  'https://www.comics.org/issue/731506/',
#  'https://www.comics.org/issue/875587/',
#  'https://www.comics.org/issue/740788/',
#  'https://www.comics.org/issue/875588/',
#  'https://www.comics.org/issue/746131/',
#  'https://www.comics.org/issue/875193/',
#  'https://www.comics.org/issue/756186/',
#  'https://www.comics.org/issue/875338/',
#  'https://www.comics.org/issue/760340/',
#  'https://www.comics.org/issue/875350/',
#  'https://www.comics.org/issue/768550/',
#  'https://www.comics.org/issue/771714/',
#  'https://www.comics.org/issue/776236/',
#  'https://www.comics.org/issue/781989/',
#  'https://www.comics.org/issue/784363/',
#  'https://www.comics.org/issue/791613/',
#  'https://www.comics.org/issue/795591/',
#  'https://www.comics.org/issue/806057/',
#  'https://www.comics.org/issue/814172/',
#  'https://www.comics.org/issue/817699/',
#  'https://www.comics.org/issue/824988/',
#  'https://www.comics.org/issue/841145/',
#  'https://www.comics.org/issue/852979/',
#  'https://www.comics.org/issue/865938/']

# %%
# take an issue url from the covers gallery..
issue_url = issue_urls[11]

issue_html = webscraper.simple_get(issue_url)
issue_soup = webscraper.transform_simple_get_html(issue_html)

# %%
issue_url
# Out:
# 'https://www.comics.org/issue/703055/'

# %%
def get_issue_metadata(soup, name):
    if len(soup.find_all('dd', id=name)) > 0:
        if (name != 'issue_indicia_publisher') & (name != 'issue_brand'):
            return soup.find_all('dd', id=name)[0].contents[0].strip()
        else:
            return soup.find_all('dd', id=name)[0].find('a').contents[0]
    else:
        return ""
                    
get_issue_metadata(issue_soup, name='issue_brand')
# get_issue_metadata(issue_soup, name='issue_price')


# issue_soup.find_all('dd', id='issue_indicia_publisher')[0].find('a').contents[0]
# Out:
# 'DC [swirl]'

# %%
# get metadata from issue url

# title, price, pages, color, dimension, paper_stock, binding, publishing_format
metadata = {}

metadata['title'] = soup.find('title').contents[0].replace('\n', '').strip().split(' :: ')[-1]
metadata['issue_price'] = soup.find_all('dd', id='issue_price')[0].contents[0].strip()
metadata['issue_pages'] = soup.find_all('dd', id='issue_pages')[0].contents[0].strip()
metadata['format_color'] = soup.find_all('dd', id='format_color')[0].contents[0].strip()
metadata['format_dimensions'] = soup.find_all('dd', id='format_dimensions')[0].contents[0].strip()
metadata['format_paper_stock'] = soup.find_all('dd', id='format_paper_stock')[0].contents[0].strip()
metadata['format_binding'] = soup.find_all('dd', id='format_binding')[0].contents[0].strip()
metadata['format_publishing_format'] = soup.find_all('dd', id='format_publishing_format')[0].contents[0].strip()


# get cover section
cover = soup.find("div", {"class": "cover"})
metadata['indexer_notes'] = " | ".join([x.contents[0].replace('\n', '').strip() for x in issue_soup.find_all('p')])

all_issue_credits = list(zip(issue_soup.find_all('span', {'class': 'credit_label'}),  issue_soup.find_all('span', {'class': 'credit_value'})))
metadata['synopsis'] = " | ".join(list(filter(lambda x: x != '', [x[1].contents[0] if x[0].contents[0] == 'Synopsis' else '' for x in all_issue_credits])))

# editing, script, pencils, inks, colors, letters, characters, etc...
cover_credits = list(zip(
    [result.contents[0] for result in cover.find_all('span', {'class': 'credit_label'})],
    [result.contents[0] for result in cover.find_all('span', {'class': 'credit_value'})]
))

metadata.update({'cover_{}'.format(x.lower()): y for x, y in cover_credits})
metadata
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-357-e1fa45c3537d> in <module>
#       5
#       6 metadata['title'] = soup.find('title').contents[0].replace('\n', '').strip().split(' :: ')[-1]
# ----> 7 metadata['issue_price'] = soup.find_all('dd', id='issue_price')[0].contents[0].strip()
#       8 metadata['issue_pages'] = soup.find_all('dd', id='issue_pages')[0].contents[0].strip()
#       9 metadata['format_color'] = soup.find_all('dd', id='format_color')[0].contents[0].strip()
#
# IndexError: list index out of range

# %%
" | ".join([x.contents[0].replace('\n', '').strip() for x in issue_soup.find_all('p')])

# issue_soup
# Out:
# 'This issue has variants. | Indicia reads: Adventure Comics #6/Adventure Comics #509 (Variant Cover).'

# %%
all_issue_credits = list(zip(issue_soup.find_all('span', {'class': 'credit_label'}),  issue_soup.find_all('span', {'class': 'credit_value'})))
" | ".join(list(filter(lambda x: x != '', [x[1].contents[0] if x[0].contents[0] == 'Synopsis' else '' for x in all_issue_credits])))
# Out:
# 'Luthor sends Superboy across time and space to retrieve the ingredients he needs to cure his sister Lena. But immediately after restoring Lena to health, Luthor shows his true colors. In anger, Superboy strikes out at Luthor, but is stopped by Brainiac. After a brief skirmish, Luthor and Brainiac teleport away, leaving Superboy to pick up the pieces. Later, in space, Luthor gazes on his next experiment.'

# %%
# issue_credit_labels = [x.contents[0] for x in  issue_soup.find_all('span', {'class': 'credit_label'})]
# issue_credit_values = [x.contents[0] for x in  issue_soup.find_all('span', {'class': 'credit_value'})]

# issue_credits = dict(zip(issue_credit_labels, issue_credit_values))
# issue_credits['Script']
# issue_credits['Synopsis']

# %%
# issue_credits

# %%
# href = cover.find("div", {'coverImage'}).a['href']
# cover_img_url = 'https://www.comics.org' + href
# cover_img_url

# %%
# raw_html = webscraper.simple_get(cover_img_url)
# html = BeautifulSoup(raw_html, 'html.parser')
# images = html.select('img')

# cover_images = list(filter(lambda x:'files1.comics.org//img/' in x['src'], images))

# cover_image = cover_images[0]['src']
# cover_image

# %%
# issue_title = metadata['title']
# issue_title

# %%
# save_to = './' + issue_title + '.jpg'

# urllib.request.urlretrieve(cover_image, save_to)
